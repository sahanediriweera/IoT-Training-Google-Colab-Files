# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 13180, done.
# remote: Total 13180 (delta 0), reused 0 (delta 0), pack-reused 13180
# Receiving objects: 100% (13180/13180), 12.00 MiB | 24.97 MiB/s, done.
# Resolving deltas: 100% (9164/9164), done.

# %%
pip install pytube
# Out:
# ...
#      |████████████████████████████████| 56 kB 2.4 MB/s
# ...

# %%
from pytube import YouTube
yt = YouTube("https://www.youtube.com/watch?v=hSIYGZhRGd4")
yt = yt.get('mp4', '720p')
yt.download('/path/to/download/directory')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-1e6d2ee129f4> in <module>()
#       1 from pytube import YouTube
#       2 yt = YouTube("https://www.youtube.com/watch?v=hSIYGZhRGd4")
# ----> 3 yt = yt.get('mp4', '720p')
#       4 yt.download('/path/to/download/directory')
#
# AttributeError: 'YouTube' object has no attribute 'get'

# %%
# !YouTube("https://www.youtube.com/watch?v=hSIYGZhRGd4").streams.first().download('t2vi')
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `"https://www.youtube.com/watch?v=hSIYGZhRGd4"'
# /bin/bash: -c: line 0: `YouTube("https://www.youtube.com/watch?v=hSIYGZhRGd4").streams.first().download('t2vi')'

# %%
from pytube import YouTube
import os

def downloadYouTube(videourl, path):

    yt = YouTube(videourl)
    yt = yt.streams.filter(progressive=True, file_extension='mp4').order_by('resolution').desc().first()
    if not os.path.exists(path):
        os.makedirs(path)
    yt.download(path)

# %%
downloadYouTube('https://www.youtube.com/watch?v=zNyYDHCg06c', './content/FindingNemo1')
# Out:
# ---------------------------------------------------------------------------
# RegexMatchError                           Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pytube/__main__.py in fmt_streams(self)
#     180         try:
# --> 181             extract.apply_signature(stream_manifest, self.vid_info, self.js)
#     182         except exceptions.ExtractError:
#
# /usr/local/lib/python3.7/dist-packages/pytube/extract.py in apply_signature(stream_manifest, vid_info, js)
#     408     """
# --> 409     cipher = Cipher(js=js)
#     410
#
# /usr/local/lib/python3.7/dist-packages/pytube/cipher.py in __init__(self, js)
#      42
# ---> 43         self.throttling_plan = get_throttling_plan(js)
#      44         self.throttling_array = get_throttling_function_array(js)
#
# /usr/local/lib/python3.7/dist-packages/pytube/cipher.py in get_throttling_plan(js)
#     404     """
# --> 405     raw_code = get_throttling_function_code(js)
#     406
#
# ...

# %%
pip install --upgrade youtube-dl
# Out:
# ...
#      |████████████████████████████████| 1.9 MB 5.2 MB/s
# ...

# %%
from __future__ import unicode_literals
import youtube_dl

ydl_opts = {}
with youtube_dl.YoutubeDL(ydl_opts) as ydl:
    ydl.download(['https://www.youtube.com/watch?v=hSIYGZhRGd4'])
# Out:
# [youtube] hSIYGZhRGd4: Downloading webpage
# WARNING: Requested formats are incompatible for merge and will be merged into mkv.
# [download] Destination: Central Park People Watching-hSIYGZhRGd4.f137.mp4
# [download]  12.9% of 234.54MiB at 68.18KiB/s ETA 51:08
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-c44e2c6aedb8> in <module>()
#       4 ydl_opts = {}
#       5 with youtube_dl.YoutubeDL(ydl_opts) as ydl:
# ----> 6     ydl.download(['https://www.youtube.com/watch?v=hSIYGZhRGd4'])
#
# /usr/local/lib/python3.7/dist-packages/youtube_dl/YoutubeDL.py in download(self, url_list)
#    2067                 # It also downloads the videos
#    2068                 res = self.extract_info(
# -> 2069                     url, force_generic_extractor=self.params.get('force_generic_extractor', False))
#    2070             except UnavailableVideoError:
# ...

# %%
from __future__ import unicode_literals
import youtube_dl

ydl_opts = {}
with youtube_dl.YoutubeDL(ydl_opts) as ydl:
    ydl.download(['https://www.youtube.com/watch?v=YzcawvDGe4Y'])

# %%
from os import path
import torch 
import numpy as np 
import cv2
import matplotlib.pyplot as plt

model = torch.hub.load('ultralytics/yolov5','custom',path='best2.pt',force_reload=True)

cap = cv2.VideoCapture('vid4.mp4')

while cap.isOpened():
    ret, frame = cap.read()

    results = model(frame)

    cv2.imshow('YOLO',np.squeeze(results.render()))

    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
