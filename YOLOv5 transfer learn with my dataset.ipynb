# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 13324, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 13324 (delta 33), reused 37 (delta 29), pack-reused 13277
# Receiving objects: 100% (13324/13324), 12.00 MiB | 31.43 MiB/s, done.
# Resolving deltas: 100% (9281/9281), done.

# %%
# !cd yolov5 && pip install wandb -qr requirements.txt
# Out:
#      |████████████████████████████████| 1.8 MB 9.1 MB/s
#      |████████████████████████████████| 596 kB 59.6 MB/s
#      |████████████████████████████████| 145 kB 68.5 MB/s
#      |████████████████████████████████| 181 kB 67.3 MB/s
#      |████████████████████████████████| 63 kB 1.7 MB/s
# ...

# %%
# !apt intall unzip
# Out:
# E: Invalid operation intall

# %%
# !unzip labels
# Out:
# Archive:  labels.zip
#   inflating: labels/0.txt
#   inflating: labels/1.txt
#   inflating: labels/10.txt
#   inflating: labels/100.txt
#   inflating: labels/101.txt
#   inflating: labels/102.txt
#   inflating: labels/103.txt
#   inflating: labels/104.txt
#   inflating: labels/105.txt
#   inflating: labels/106.txt
#   inflating: labels/107.txt
#   inflating: labels/108.txt
#   inflating: labels/109.txt
#   inflating: labels/11.txt
#   inflating: labels/110.txt
#   inflating: labels/111.txt
#   inflating: labels/112.txt
#   inflating: labels/113.txt
#   inflating: labels/114.txt
#   inflating: labels/115.txt
#   inflating: labels/116.txt
#   inflating: labels/117.txt
#   inflating: labels/118.txt
#   inflating: labels/119.txt
#   inflating: labels/12.txt
#   inflating: labels/120.txt
#   inflating: labels/121.txt
#   inflating: labels/122.txt
#   inflating: labels/123.txt
#   inflating: labels/124.txt
#   inflating: labels/125.txt
#   inflating: labels/126.txt
# ...

# %%
pip install kaggle

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d constantinwerner/human-detection-dataset --force
# Out:
# ...
#  96% 249M/260M [00:01<00:00, 130MB/s]
# 100% 260M/260M [00:01<00:00, 177MB/s]

# %%
# !unzip human-detection-dataset
# Out:
# Archive:  human-detection-dataset.zip
#   inflating: human detection dataset/0/0.png
#   inflating: human detection dataset/0/1.png
#   inflating: human detection dataset/0/10.png
#   inflating: human detection dataset/0/100.png
#   inflating: human detection dataset/0/101.png
#   inflating: human detection dataset/0/102.png
#   inflating: human detection dataset/0/103.png
#   inflating: human detection dataset/0/104.png
#   inflating: human detection dataset/0/105.png
#   inflating: human detection dataset/0/106.png
#   inflating: human detection dataset/0/107.png
#   inflating: human detection dataset/0/108.png
#   inflating: human detection dataset/0/109.png
#   inflating: human detection dataset/0/11.png
#   inflating: human detection dataset/0/110.png
#   inflating: human detection dataset/0/111.png
#   inflating: human detection dataset/0/112.png
#   inflating: human detection dataset/0/113.png
#   inflating: human detection dataset/0/114.png
# ...

# %%
ls
# Out:
#  data/                         kaggle.json    yolov5/
# 'human detection dataset'/     labels.zip
#  human-detection-dataset.zip   sample_data/

# %%
# !cd yolov5 && python train.py --img 640 --freeze 20 --batch 16 --epochs 60 --weights yolov5s.pt --data dataset.yml
# Out:
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: W&B disabled due to login timeout.
# train: weights=yolov5s.pt, cfg=, data=dataset.yml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=60, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[20], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-179-gf3fecf9 torch 1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...
